# %%
#Beginning: Download latest data from https://github.com/CSSEGISandData/COVID-19/tree/master/csse_covid_19_data/csse_covid_19_time_series 


import pandas as pd 

confirmed_raw = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv", index_col = 'Country/Region')
confirmed = pd.DataFrame(confirmed_raw.groupby('Country/Region').sum())
confirmed = confirmed.sort_values(by='3/15/20')

deaths_raw = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv", index_col = 'Country/Region')
deaths = pd.DataFrame(deaths_raw.groupby('Country/Region').sum())

#recovered_raw = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Recovered.csv", index_col = 'Country/Region')
#recovered = pd.DataFrame(recovered_raw.groupby('Country/Region').sum())

confirmed.to_csv('confirmed.csv')
deaths.to_csv('deaths.csv')
#recovered.to_csv('recovered.csv')

# %%
#Gather population by country from https://raw.githubusercontent.com/datasets/population/master/data/population.csv
population_raw = pd.read_csv("https://raw.githubusercontent.com/datasets/population/master/data/population.csv", index_col = 'Country Name')

population = pd.DataFrame(population_raw).loc[population_raw['Year'] == 2016]
#population.to_csv('population.csv')
#population

# %%
selection1 = confirmed.loc[['Germany','France','Austria','Switzerland','UK','Poland','Denmark','Pakistan','Egypt','Korea, South','Turkey']]
cf1 = selection1.transpose().tail(20)
#cf1
#cf11 = cf1.sort_values(by='3/15/20')

# %%
cf1.plot.line(title='Confirmed - Log scale (y axis)',logy=True)

# %%
cf1.plot.line(title='Confirmed (regular scale)')

# %%
selection2 = confirmed.loc[['Germany','China','Italy','US','Spain','Iran','France','UK','Korea, South','India','Pakistan','Turkey']]
cf2 = selection2.transpose().tail(30)

cf2.plot.line(title='Confirmed2')

# %%
selection3 = deaths.loc[['Germany','Italy','France','Spain','US','Iran','China','India','Pakistan','Korea, South','Turkey']]
ds1 = selection3.transpose().tail(30)

ds1.plot.line(title='Deaths')

# %%
selection4 = deaths.loc[['Germany','Austria','Switzerland','UK','Poland','Denmark','Pakistan','Korea, South','Turkey']]

ds2 = selection4.transpose().tail(15)

ds2.plot.line(title='Deaths2')

# %%
ds2.plot.line(title='Deaths2 - Log scale (y)',logy=True)

# %%
selection4 = deaths.loc[['Austria','UK','Poland','Denmark','Pakistan','Turkey']]
ds2 = selection4.transpose().tail(15)

ds2.plot.line(title='Deaths3')
